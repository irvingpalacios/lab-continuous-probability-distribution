# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.55592886 2.46616626 2.96360245 2.16766671 2.47774859 2.800262
#  2.52398414 2.97380927 2.80055402 2.45036903]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
def random (bottom,ceiling,count):
  x = uniform.rvs(size=count)
  randoms  = bottom + (ceiling-bottom)*x
  return randoms

# %%
f1=random(10,15,100)
f2=random(10,60,1000)

# %%
import matplotlib.pyplot as plt

# %%
fig, [ax1, ax2] = plt.subplots(1,2)
ax1.hist(f1,bins=10)
ax1.set_title('f1 PLOT') 
ax1.set_xlabel('x label')
ax1.set_ylabel('y label')

ax2.hist(f2,bins=10)
ax2.set_title('f2 PLOT')
ax2.set_xlabel('x label')


plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

#The ranges of the functions are different.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
# your code here

import math
from scipy.stats import norm

# %%
def normal_dist (mean,std,count):
  x = norm.rvs(size=count)
  randoms_norm  = mean + (std)*x
  return randoms_norm

# %%
nor1=normal_dist(10,1,1000)
nor2=normal_dist(10,50,1000)

# %%
# your code here

fig, [ax1, ax2] = plt.subplots(1,2,sharey=True)
ax1.hist(nor1,bins=100)
ax1.set_title('nor1 PLOT') 
ax1.set_xlabel('x label')
ax1.set_ylabel('y label')

ax2.hist(nor2,bins=100)
ax2.set_title('nor2 PLOT')
ax2.set_xlabel('x label')


plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

#On the X axis albel we can appreciate that is bigger because the std value we gave

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
#Delete this row or ## it if you are on jupyter


from google.colab import drive
drive.mount('/content/drive')
vehicles = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/LABS/Módulo 2/lab-continuous-probability-distribution-master/your-code/vehicles.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
import pandas as pd
import numpy as np

#vehicles = pd.read_csv('vehicles.csv')

# %%
vehicles.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
# your code here

plt.hist(vehicles['Fuel Barrels/Year'], bins=50);
plt.title('Fuel Barrels/Year HIST');

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
plt.hist(vehicles['CO2 Emission Grams/Mile'], bins=50);
plt.title('CO2 Emission Grams/Mile HIST');

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
plt.hist(vehicles['Combined MPG'], bins=50);
plt.title('Combined MPG HIST');

# %% [markdown]
# Plotting the three of them at the same time

# %%
fig, [ax1, ax2, ax3] = plt.subplots(1,3,sharex=False, sharey=True)

ax1.hist(vehicles['Fuel Barrels/Year'], bins=50)
ax1.set_title('Fuel Barrels/Year') 

ax2.hist(vehicles['CO2 Emission Grams/Mile'], bins=50)
ax2.set_title('CO2 Emission Grams/Mile')

ax3.hist(vehicles['Combined MPG'], bins=50)
ax3.set_title('Combined MPG HIST')

plt.tight_layout()
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here

#The first one present the caracteristics of a normal distribuited  one.
#Doing a skim to the plots the second and the third do not look like symmetrical to the mean value

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 1 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
from scipy.stats import expon

# %%
# your code here

def expo_dist (lambd,count):
  x = np.random.exponential(scale=lambd,size=count)
  return x

# %%
exp1 = expo_dist(10,10000)
exp2 = expo_dist(1,10000)

# %%
fig, [ax1, ax2] = plt.subplots(1,2, sharey=True, sharex=True)

ax1.hist(exp1, bins=100)
ax1.set_title('exp1') 

ax2.hist(exp2, bins=100)
ax2.set_title('exp2')


plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here

#We can appreciate that a low mean affects on how fast our plot tends to zero "faster"
#

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)

less15=expon.cdf(x=15,scale=10)
less15
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here

# %%
1-less15
# Out:
# 0.2231301601484298
